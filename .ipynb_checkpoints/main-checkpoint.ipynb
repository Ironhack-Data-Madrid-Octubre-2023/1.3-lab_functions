# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Functions</a></span><ul class="toc-item"><li><span><a href="#1.-Write-a-function-that-returns-the-greater-of-two-numbers" data-toc-modified-id="1.-Write-a-function-that-returns-the-greater-of-two-numbers-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>1. Write a function that returns the greater of two numbers</a></span></li><li><span><a href="#2.-Now-write-a-function-that-returns-the-largest-element-on-a-list" data-toc-modified-id="2.-Now-write-a-function-that-returns-the-largest-element-on-a-list-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>2. Now write a function that returns the largest element on a list</a></span></li><li><span><a href="#3.-Write-a-function-that-sums-all-the-elements-on-a-list" data-toc-modified-id="3.-Write-a-function-that-sums-all-the-elements-on-a-list-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>3. Write a function that sums all the elements on a list</a></span></li><li><span><a href="#4.-Write-another-function-that-multiplies-all-the-elements-on-a-list" data-toc-modified-id="4.-Write-another-function-that-multiplies-all-the-elements-on-a-list-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>4. Write another function that multiplies all the elements on a list</a></span></li><li><span><a href="#5.-Now-combine-those-two-ideas-and-write-a-function-that-receives-a-list-and-either-&quot;+&quot;-or-&quot;*&quot;-and-outputs-acordingly" data-toc-modified-id="5.-Now-combine-those-two-ideas-and-write-a-function-that-receives-a-list-and-either-&quot;+&quot;-or-&quot;*&quot;-and-outputs-acordingly-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly</a></span></li><li><span><a href="#6.-Write-a-function-that-returns-the-factorial-of-a-number." data-toc-modified-id="6.-Write-a-function-that-returns-the-factorial-of-a-number.-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>6. Write a function that returns the factorial of a number.</a></span></li><li><span><a href="#7.-Write-a-function-that-takes-a-list-and-returns-a-list-of-the-unique-values." data-toc-modified-id="7.-Write-a-function-that-takes-a-list-and-returns-a-list-of-the-unique-values.-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>7. Write a function that takes a list and returns a list of the unique values.</a></span></li><li><span><a href="#8.-Write-a-function-that-returns-the-mode-of-a-list,-i.e.:-the-element-that-appears-the-most-times." data-toc-modified-id="8.-Write-a-function-that-returns-the-mode-of-a-list,-i.e.:-the-element-that-appears-the-most-times.-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.</a></span></li><li><span><a href="#9.-Write-a-function-that-calculates-the-standard-deviation-of-a-list." data-toc-modified-id="9.-Write-a-function-that-calculates-the-standard-deviation-of-a-list.-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>9. Write a function that calculates the standard deviation of a list.</a></span></li><li><span><a href="#10.-Write-a-function-to-check-if-a-string-is-a-pangram,-i.e.:-if-it-contains-all-the-letters-of-the-alphabet-at-least-once.-Mind-that-the-strings-may-contain-characters-that-are-not-letters." data-toc-modified-id="10.-Write-a-function-to-check-if-a-string-is-a-pangram,-i.e.:-if-it-contains-all-the-letters-of-the-alphabet-at-least-once.-Mind-that-the-strings-may-contain-characters-that-are-not-letters.-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.</a></span></li><li><span><a href="#11.-Write-a-function-that-receives-a-string-of-comma-separated-words-and-returns-a-string-of-comma-separated-words-sorted-alphabetically." data-toc-modified-id="11.-Write-a-function-that-receives-a-string-of-comma-separated-words-and-returns-a-string-of-comma-separated-words-sorted-alphabetically.-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.</a></span></li><li><span><a href="#12.-Write-a-function-to-check-if-a-given-password-is-strong-(at-least-8-characters,-at-least-one-lower-case,-at-least-one-upper-case,-at-least-one-number-and-at-least-one-special-character).-It-should-output-True-if-strong-and-False-if-not." data-toc-modified-id="12.-Write-a-function-to-check-if-a-given-password-is-strong-(at-least-8-characters,-at-least-one-lower-case,-at-least-one-upper-case,-at-least-one-number-and-at-least-one-special-character).-It-should-output-True-if-strong-and-False-if-not.-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
#Run this cell

from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a > b:
        return a
    else:
        return b

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.078s
#
# OK

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(arr):
    result = 0

    for i in arr:
        
        if i >= result: result = i

    return result

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.084s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(arr):
    Total = 0
    
    for i in arr:
        Total += i
        
    return Total

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.083s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(arr):
    
    total = 1
    
    for i in arr:
        total *= i
        
    return total

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.074s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper):
    if oper == '+':
        total = 0
        for i in arr:
            total += i
    elif oper == '*':
        total = 1
        for i in arr:
            total *= i
    
    return total

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.082s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    
    if n < 0:
        return "Factorial no definido"
        
    elif n == 0:
        return 1
    
    else:
        return n * factorial(n-1)
        
    
print(factorial(9))
# Out:
# 362880

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.088s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(arr):
    unique_list = []
    for i in arr:
        if i not in unique_list:
            unique_list.append(i)
            
    return unique_list

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.178s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    freq_dict = {}
    for i in arr:
        if i in freq_dict:
            freq_dict[i] += 1
        else:
            freq_dict[i] = 1
            
    greater = 0
    actual = 0
    
    for key, value in freq_dict.items():
        if(value > actual):
            greater = key
    return actual

# %%
# Thiswill test your function 
test_mode(mode_counter)
# Out:
# FFFFFFFFF.FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF.FFFFFFFFF.FFFFFFFFFF.FFFFFFFFFFFFFFFFFFFFFFFFFFF.FFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 10 : Should be 10
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 5 : Should be 5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 15 != 20 : Should be 20
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 15 != 7 : Should be 7
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 10 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 19 : Should be 19
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 25 != 7 : Should be 7
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 14 != 4 : Should be 4
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 12 : Should be 12
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 16 : Should be 16
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 13 : Should be 13
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 10 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 9 : Should be 9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 21 != 8 : Should be 8
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 21 != 4 : Should be 4
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 1 : Should be 1
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 19 : Should be 19
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 5 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 5 : Should be 5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 15 != 18 : Should be 18
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 2 != 3 : Should be 3
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 19 != 24 : Should be 24
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 14 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 24 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 5 : Should be 5
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 18 : Should be 18
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 20 : Should be 20
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 18 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 10 != 19 : Should be 19
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 21 != 13 : Should be 13
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 25 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 9 != 12 : Should be 12
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 9 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 24 : Should be 24
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 14 : Should be 14
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 19 != 18 : Should be 18
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 10 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 21 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 18 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 1 : Should be 1
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 24 : Should be 24
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 16 : Should be 16
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 24 : Should be 24
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 19 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 15 : Should be 15
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 6 != 13 : Should be 13
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 24 != 19 : Should be 19
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 9 != 2 : Should be 2
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 7 != 14 : Should be 14
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 15 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 11 != 3 : Should be 3
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 6 != 13 : Should be 13
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 24 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 6 != 1 : Should be 1
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 10 : Should be 10
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 7 != 2 : Should be 2
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 18 != 20 : Should be 20
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 6 != 18 : Should be 18
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 2 != 10 : Should be 10
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 2 : Should be 2
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 2 != 20 : Should be 20
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 25 != 15 : Should be 15
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 9 : Should be 9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 5 : Should be 5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 8 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 14 : Should be 14
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 20 != 1 : Should be 1
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 9 != 2 : Should be 2
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 9 != 5 : Should be 5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 18 : Should be 18
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 6 != 18 : Should be 18
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 2 : Should be 2
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 9 : Should be 9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 24 != 12 : Should be 12
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.161s
#
# FAILED (failures=95)

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
from statistics import stdev
def st_dev(arr):
    mean = 0
    n = 0
    for i in arr:
        n += 1
        mean += (i - mean)/n
    
    sumadifraices = 0
    
    for i in arr:
        sumadifraices += (i - mean)** 2
        
        satandard_deviation = (sumadifraices / (n - 1)) ** 0.5
    
    return sa

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.084s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    
    alfabeto = 'abcdefghijklmnopqrstuvwxyz'
    
    string = string.lower()
    
    for i in alfabeto:
        if i not in string:
            return False
            
    return True

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.026s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    
    palabras = string.split(',')
    
    palabras_alfabatic = sorted(palabras)
    
    string_alfabetic = ""
    
    for palabra in palabras_alfabetic:
        string_alfabetic += palabra + ','
    
    return string_alfabetic

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# ...
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\508186815.py", line 9, in sort_alpha
#     for palabra in palabras_alfabetic:
#                    ^^^^^^^^^^^^^^^^^^
# NameError: name 'palabras_alfabetic' is not defined
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.131s
#
# FAILED (errors=100)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
def check_pass(string):
    length = 0
    for _ in string:
        length += 1
        
    if length < 8:
        return False
    
    tiene_minusculas = False
    for letra in string:
        if letra.islower():
            tiene_minusculas = True
            break
    if not tiene_mainusculas:
        return False

    tiene_mayusuculas = False
    for letra in string:
        if letra.isupper():
            tiene_mayusculas = True
            break
    if not tiene_mayusculas:
        return False
    
    tiene_numero = False
    for letra in string:
        if string.isdigit():
            tiene_numero = True
            break
    if not tiene_numero:
        return False
    
    caracteres_especiales = ["!@#$%^&*()_+{}[]:;<>,.?~\\/-"]
    tiene_caracespe = False
    for letra in string:
        if letra in caracteres_especiales:
            tiene_caracespe = True
            break
    if not tiene_caracespe:
        return False

    return True

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# EEE.EEEE.E.EEEEEEE...E.EEEE..E.EEEEEEEEEEEE.EEEEEEEEE..EEE.EEEEEEEEEEE.EEEE.E.EEE..E.E.EEE.E.EEEE...
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ferna\Desktop\IRONHACK\1.3-lab_functions\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^
#   File "C:\Users\ferna\AppData\Local\Temp\ipykernel_9564\1222085991.py", line 14, in check_pass
#     if not tiene_mainusculas:
#            ^^^^^^^^^^^^^^^^^
# NameError: name 'tiene_mainusculas' is not defined
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.111s
#
# FAILED (errors=74)
